# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafi14078/Machine_Learning/blob/main/Pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["Nafi","Meraz","Tasib","Robin"],
    "age":[20,21,22,23],
    "city":["Dhaka","chattogram","Tangail","Jamalpur"]
}

# %%
p1=pd.DataFrame(dict1)

# %%
p1
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
p1.to_csv("file.csv")

# %%
p1.to_csv("false.csv",index=False)

# %%
p1.head(2)
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram

# %%
p1.tail(2)
# Out:
#     name  age      city
# 2  Tasib   22   Tangail
# 3  Robin   23  Jamalpur

# %%
p1.describe()
# Out:
#              age
# count   4.000000
# mean   21.500000
# std     1.290994
# min    20.000000
# 25%    20.750000
# 50%    21.500000
# 75%    22.250000
# max    23.000000

# %%
p1
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
Nafi=pd.read_csv("false.csv")

# %%
Nafi
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
Nafi['age']
# Out:
# 0    20
# 1    21
# 2    22
# 3    23
# Name: age, dtype: int64

# %%
Nafi['age'][0]
# Out:
# np.int64(20)

# %%
Nafi['age'][0]=50
# Out:
# <ipython-input-407-1116985109>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nafi['age'][0]=50

# %%
Nafi['age'][0]
# Out:
# np.int64(50)

# %%
Nafi
# Out:
#     name  age        city
# 0   Nafi   50       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
Nafi['age'][0]=20
# Out:
# <ipython-input-410-776111353>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Nafi['age'][0]=20
# <ipython-input-410-776111353>:1: SettingWithCopyWarning:
# ...

# %%
Nafi
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
Nafi.to_csv('nafi.csv')

# %%
Nafi
# Out:
#     name  age        city
# 0   Nafi   20       Dhaka
# 1  Meraz   21  chattogram
# 2  Tasib   22     Tangail
# 3  Robin   23    Jamalpur

# %%
Nafi.index=['one','two','three','four']

# %%
Nafi
# Out:
#         name  age        city
# one     Nafi   20       Dhaka
# two    Meraz   21  chattogram
# three  Tasib   22     Tangail
# four   Robin   23    Jamalpur

# %% [markdown]
# Pandas:Series and DataFrame

# %%
Ser=pd.Series(np.random.rand(34))

# %%
Ser
# Out:
# 0     0.535137
# 1     0.385468
# 2     0.496465
# 3     0.572911
# 4     0.117835
# 5     0.354120
# 6     0.797515
# 7     0.796195
# 8     0.599466
# 9     0.577042
# 10    0.551777
# 11    0.800646
# 12    0.028876
# 13    0.605782
# 14    0.062108
# 15    0.665206
# 16    0.646361
# 17    0.847286
# 18    0.329836
# 19    0.453369
# 20    0.850492
# 21    0.222655
# 22    0.739422
# 23    0.093076
# 24    0.301316
# 25    0.279007
# 26    0.591616
# 27    0.510285
# 28    0.068382
# 29    0.148021
# 30    0.650783
# 31    0.580308
# 32    0.655399
# 33    0.105283
# dtype: float64

# %%
type(Ser)
# Out:
# pandas.core.series.Series

# %%
dat=pd.DataFrame(np.random.rand(334,5))

# %%
dat
# Out:
#             0         1         2         3         4
# 0    0.635413  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4    0.691670  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.head(5)
# Out:
#           0         1         2         3         4
# 0  0.635413  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4  0.691670  0.866678  0.229961  0.386622  0.178197

# %%
dat.tail(5)
# Out:
#             0         1         2         3         4
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550

# %%
dat
# Out:
#             0         1         2         3         4
# 0    0.635413  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4    0.691670  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
dat[0][0]="Riad"
# Out:
# <ipython-input-427-2048685821>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat[0][0]="Riad"
# ...

# %%
dat
# Out:
#             0         1         2         3         4
# 0        Riad  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
dat.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
dat.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dat.describe()
# Out:
#                 1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000
# mean     0.476884    0.483811    0.495386    0.508002
# std      0.290693    0.294987    0.282396    0.295706
# min      0.000297    0.000244    0.003684    0.002439
# 25%      0.218315    0.214845    0.264189    0.253243
# 50%      0.466378    0.490196    0.493521    0.508925
# 75%      0.732405    0.724118    0.734835    0.771963
# max      0.992027    0.999280    0.998649    0.998207

# %%
dat[0][0]=0.3
# Out:
# <ipython-input-433-2759798215>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat[0][0]=0.3
# <ipython-input-433-2759798215>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
# ...

# %%
dat.head()
# Out:
#           0         1         2         3         4
# 0       0.3  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.to_numpy()
# Out:
# array([[0.3, 0.03561344729695515, 0.3509653155759961, 0.7750387217804493,
#         0.9213222256546313],
#        [0.6582333362312736, 0.853413988365286, 0.3613975941376846,
#         0.7669421234679547, 0.4540497453816964],
#        [0.7753621426547376, 0.02715117145185908, 0.11258261613284459,
#         0.6279925401902153, 0.29080175391422136],
#        ...,
#        [0.7663952600057711, 0.19217156116386247, 0.036961174999583624,
#         0.6445315154392727, 0.44825154887075136],
#        [0.11674840663909491, 0.42900200718968373, 0.8982247622806899,
#         0.3369833565049052, 0.5992733655290854],
#        [0.6846277617322826, 0.2017934638805765, 0.10140393257126734,
#         0.7975611199313295, 0.7065501050527393]], dtype=object)

# %%
dat
# Out:
#             0         1         2         3         4
# 0         0.3  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
dat.T
# Out:
#         0         1         2         3         4         5         6    \
# 0       0.3  0.658233  0.775362  0.511142   0.69167  0.658535  0.289452
# 1  0.035613  0.853414  0.027151  0.902692  0.866678   0.00871  0.908032
# 2  0.350965  0.361398  0.112583  0.463455  0.229961  0.336379   0.31043
# 3  0.775039  0.766942  0.627993  0.435931  0.386622  0.770803  0.282188
# 4  0.921322   0.45405  0.290802  0.650377  0.178197  0.602723  0.210729
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.240536  0.548403  0.763226  ...  0.880094  0.934111  0.735189  0.993954
# 1  0.982353  0.906158  0.437688  ...  0.185889  0.805029   0.42563   0.32145
# 2  0.491042  0.742218    0.1934  ...  0.252343  0.456165  0.762935  0.679804
# 3  0.526299  0.202335  0.314306  ...  0.239589  0.987226  0.754053  0.743279
# 4  0.634271  0.810916  0.247305  ...  0.202955  0.746361  0.204095  0.208214
#
#         328       329       330       331       332       333
# ...

# %%
dat.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3         4
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# ..        ...       ...       ...       ...       ...
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 0         0.3  0.035613  0.350965  0.775039  0.921322
#
# [334 rows x 5 columns]

# %%
dat.sort_index(axis=1,ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.921322  0.775039  0.350965  0.035613       0.3
# 1    0.454050  0.766942  0.361398  0.853414  0.658233
# 2    0.290802  0.627993  0.112583  0.027151  0.775362
# 3    0.650377  0.435931  0.463455  0.902692  0.511142
# 4    0.178197  0.386622  0.229961  0.866678   0.69167
# ..        ...       ...       ...       ...       ...
# 329  0.073199  0.416323  0.604752  0.714030  0.342325
# 330  0.689708  0.531335  0.253079  0.217949  0.155003
# 331  0.448252  0.644532  0.036961  0.192172  0.766395
# 332  0.599273  0.336983  0.898225  0.429002  0.116748
# 333  0.706550  0.797561  0.101404  0.201793  0.684628
#
# [334 rows x 5 columns]

# %%
dat1=dat

# %%
dat1[0][0]=50
# Out:
# <ipython-input-442-3401379054>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat1[0][0]=50
# <ipython-input-442-3401379054>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
# ...

# %%
dat.head()
# Out:
#           0         1         2         3         4
# 0        50  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat1=dat[:]

# %%
dat1.head()
# Out:
#           0         1         2         3         4
# 0        50  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat1=dat.copy()

# %%
dat1.head()
# Out:
#           0         1         2         3         4
# 0        50  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat1[0][0]=60
# Out:
# <ipython-input-448-259846951>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat1[0][0]=60
# <ipython-input-448-259846951>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dat1.head()
# Out:
#           0         1         2         3         4
# 0        60  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat.head()
# Out:
#           0         1         2         3         4
# 0        50  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat.loc[0,0]=45

# %%
dat.head(2)
# Out:
#           0         1         2         3         4
# 0        45  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050

# %%
dat.columns=list("ABCDE")

# %%
dat.head()
# Out:
#           A         B         C         D         E
# 0        45  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802
# 3  0.511142  0.902692  0.463455  0.435931  0.650377
# 4   0.69167  0.866678  0.229961  0.386622  0.178197

# %%
dat.loc[0,0]=70

# %%
dat.head()
# Out:
#           A         B         C         D         E     0
# 0        45  0.035613  0.350965  0.775039  0.921322  70.0
# 1  0.658233  0.853414  0.361398  0.766942  0.454050   NaN
# 2  0.775362  0.027151  0.112583  0.627993  0.290802   NaN
# 3  0.511142  0.902692  0.463455  0.435931  0.650377   NaN
# 4   0.69167  0.866678  0.229961  0.386622  0.178197   NaN

# %%
dat.drop(0,axis=0)
# Out:
#             A         B         C         D         E   0
# 1    0.658233  0.853414  0.361398  0.766942  0.454050 NaN
# 2    0.775362  0.027151  0.112583  0.627993  0.290802 NaN
# 3    0.511142  0.902692  0.463455  0.435931  0.650377 NaN
# 4     0.69167  0.866678  0.229961  0.386622  0.178197 NaN
# 5    0.658535  0.008710  0.336379  0.770803  0.602723 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.342325  0.714030  0.604752  0.416323  0.073199 NaN
# 330  0.155003  0.217949  0.253079  0.531335  0.689708 NaN
# 331  0.766395  0.192172  0.036961  0.644532  0.448252 NaN
# 332  0.116748  0.429002  0.898225  0.336983  0.599273 NaN
# 333  0.684628  0.201793  0.101404  0.797561  0.706550 NaN
#
# [333 rows x 6 columns]

# %%
dat.drop(0,axis=1)
# Out:
#             A         B         C         D         E
# 0          45  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
dat.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.361398  0.766942
# 2  0.112583  0.627993

# %%
dat.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.350965  0.775039
# 1    0.361398  0.766942
# 2    0.112583  0.627993
# 3    0.463455  0.435931
# 4    0.229961  0.386622
# ..        ...       ...
# 329  0.604752  0.416323
# 330  0.253079  0.531335
# 331  0.036961  0.644532
# 332  0.898225  0.336983
# 333  0.101404  0.797561
#
# [334 rows x 2 columns]

# %%
dat.loc[:,:]
# Out:
#             A         B         C         D         E     0
# 0          45  0.035613  0.350965  0.775039  0.921322  70.0
# 1    0.658233  0.853414  0.361398  0.766942  0.454050   NaN
# 2    0.775362  0.027151  0.112583  0.627993  0.290802   NaN
# 3    0.511142  0.902692  0.463455  0.435931  0.650377   NaN
# 4     0.69167  0.866678  0.229961  0.386622  0.178197   NaN
# ..        ...       ...       ...       ...       ...   ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199   NaN
# 330  0.155003  0.217949  0.253079  0.531335  0.689708   NaN
# 331  0.766395  0.192172  0.036961  0.644532  0.448252   NaN
# 332  0.116748  0.429002  0.898225  0.336983  0.599273   NaN
# 333  0.684628  0.201793  0.101404  0.797561  0.706550   NaN
#
# [334 rows x 6 columns]

# %%
dat=dat.drop(0,axis=1)

# %%
dat
# Out:
#             A         B         C         D         E
# 0          45  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [334 rows x 5 columns]

# %%
dat.loc[(dat['A']>0.3) &(dat['C']>0.1)]
# Out:
#             A         B         C         D         E
# 0          45  0.035613  0.350965  0.775039  0.921322
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# ..        ...       ...       ...       ...       ...
# 325  0.934111  0.805029  0.456165  0.987226  0.746361
# 326  0.735189  0.425630  0.762935  0.754053  0.204095
# 327  0.993954  0.321450  0.679804  0.743279  0.208214
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [212 rows x 5 columns]

# %%
dat.iloc[0,4]
# Out:
# np.float64(0.9213222256546313)

# %%
dat.iloc[[0,5],[1,2]]
# Out:
#           B         C
# 0  0.035613  0.350965
# 5  0.008710  0.336379

# %%
dat.head(3)
# Out:
#           A         B         C         D         E
# 0        45  0.035613  0.350965  0.775039  0.921322
# 1  0.658233  0.853414  0.361398  0.766942  0.454050
# 2  0.775362  0.027151  0.112583  0.627993  0.290802

# %%
dat.drop(0,axis=0)
# Out:
#             A         B         C         D         E
# 1    0.658233  0.853414  0.361398  0.766942  0.454050
# 2    0.775362  0.027151  0.112583  0.627993  0.290802
# 3    0.511142  0.902692  0.463455  0.435931  0.650377
# 4     0.69167  0.866678  0.229961  0.386622  0.178197
# 5    0.658535  0.008710  0.336379  0.770803  0.602723
# ..        ...       ...       ...       ...       ...
# 329  0.342325  0.714030  0.604752  0.416323  0.073199
# 330  0.155003  0.217949  0.253079  0.531335  0.689708
# 331  0.766395  0.192172  0.036961  0.644532  0.448252
# 332  0.116748  0.429002  0.898225  0.336983  0.599273
# 333  0.684628  0.201793  0.101404  0.797561  0.706550
#
# [333 rows x 5 columns]

# %%
dat.drop(['A','C'],axis=1)
# Out:
#             B         D         E
# 0    0.035613  0.775039  0.921322
# 1    0.853414  0.766942  0.454050
# 2    0.027151  0.627993  0.290802
# 3    0.902692  0.435931  0.650377
# 4    0.866678  0.386622  0.178197
# ..        ...       ...       ...
# 329  0.714030  0.416323  0.073199
# 330  0.217949  0.531335  0.689708
# 331  0.192172  0.644532  0.448252
# 332  0.429002  0.336983  0.599273
# 333  0.201793  0.797561  0.706550
#
# [334 rows x 3 columns]

# %%
dat.drop(['A','D'],axis=1,inplace=True)

# %%
dat
# Out:
#             B         C         E
# 0    0.035613  0.350965  0.921322
# 1    0.853414  0.361398  0.454050
# 2    0.027151  0.112583  0.290802
# 3    0.902692  0.463455  0.650377
# 4    0.866678  0.229961  0.178197
# ..        ...       ...       ...
# 329  0.714030  0.604752  0.073199
# 330  0.217949  0.253079  0.689708
# 331  0.192172  0.036961  0.448252
# 332  0.429002  0.898225  0.599273
# 333  0.201793  0.101404  0.706550
#
# [334 rows x 3 columns]

# %%
dat.drop([0,1],axis=0,inplace=True)

# %%
dat
# Out:
#             B         C         E
# 2    0.027151  0.112583  0.290802
# 3    0.902692  0.463455  0.650377
# 4    0.866678  0.229961  0.178197
# 5    0.008710  0.336379  0.602723
# 6    0.908032  0.310430  0.210729
# ..        ...       ...       ...
# 329  0.714030  0.604752  0.073199
# 330  0.217949  0.253079  0.689708
# 331  0.192172  0.036961  0.448252
# 332  0.429002  0.898225  0.599273
# 333  0.201793  0.101404  0.706550
#
# [332 rows x 3 columns]

# %%
dat.reset_index(drop=True,inplace=True)

# %%
dat.head(5)
# Out:
#           B         C         E
# 0  0.027151  0.112583  0.290802
# 1  0.902692  0.463455  0.650377
# 2  0.866678  0.229961  0.178197
# 3  0.008710  0.336379  0.602723
# 4  0.908032  0.310430  0.210729

# %%
dat['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
dat['B']=None

# %%
dat['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
dat.loc[:,'B']=56

# %%
dat
# Out:
#       B         C         E
# 0    56  0.112583  0.290802
# 1    56  0.463455  0.650377
# 2    56  0.229961  0.178197
# 3    56  0.336379  0.602723
# 4    56  0.310430  0.210729
# ..   ..       ...       ...
# 327  56  0.604752  0.073199
# 328  56  0.253079  0.689708
# 329  56  0.036961  0.448252
# 330  56  0.898225  0.599273
# 331  56  0.101404  0.706550
#
# [332 rows x 3 columns]

# %%
dat.dropna(axis=1)
# Out:
#       B         C         E
# 0    56  0.112583  0.290802
# 1    56  0.463455  0.650377
# 2    56  0.229961  0.178197
# 3    56  0.336379  0.602723
# 4    56  0.310430  0.210729
# ..   ..       ...       ...
# 327  56  0.604752  0.073199
# 328  56  0.253079  0.689708
# 329  56  0.036961  0.448252
# 330  56  0.898225  0.599273
# 331  56  0.101404  0.706550
#
# [332 rows x 3 columns]

# %%
dat.dropna(how='all',axis=1)
# Out:
#       B         C         E
# 0    56  0.112583  0.290802
# 1    56  0.463455  0.650377
# 2    56  0.229961  0.178197
# 3    56  0.336379  0.602723
# 4    56  0.310430  0.210729
# ..   ..       ...       ...
# 327  56  0.604752  0.073199
# 328  56  0.253079  0.689708
# 329  56  0.036961  0.448252
# 330  56  0.898225  0.599273
# 331  56  0.101404  0.706550
#
# [332 rows x 3 columns]

# %%
dat.drop_duplicates(subset=('B'),keep=False)
# Out:
# Empty DataFrame
# Columns: [B, C, E]
# Index: []

# %%
dat.shape
# Out:
# (332, 3)

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   B       332 non-null    object
#  1   C       332 non-null    float64
#  2   E       332 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 7.9+ KB

# %%
dat['B'].value_counts(dropna=False)
# Out:
# B
# 56    332
# Name: count, dtype: int64

# %%
dat['C'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: C, Length: 332, dtype: bool

# %%
dat['C'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: C, Length: 332, dtype: bool

# %%
dat2=pd.DataFrame(np.random.rand(3,2))

# %%
dat2
# Out:
#           0         1
# 0  0.325550  0.550861
# 1  0.527917  0.791631
# 2  0.909506  0.962939

# %%
dat2.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.587658  0.768477
# std    0.296526  0.207012
# min    0.325550  0.550861
# 25%    0.426734  0.671246
# 50%    0.527917  0.791631
# 75%    0.718712  0.877285
# max    0.909506  0.962939

# %%
dat2.max()
# Out:
# 0    0.909506
# 1    0.962939
# dtype: float64

# %%
dat2.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
dat2.corr()
# Out:
#          0        1
# 0  1.00000  0.96313
# 1  0.96313  1.00000

# %%
dat2.median()
# Out:
# 0    0.527917
# 1    0.791631
# dtype: float64

# %% [markdown]
# #for converting dataframe to excel or to read excel

# %%
dat2.to_excel("Nafi.xlsx",sheet_name='Sheet1')

# %%
dat2
# Out:
#           0         1
# 0  0.325550  0.550861
# 1  0.527917  0.791631
# 2  0.909506  0.962939

# %%
dat3=pd.read_excel("Nafi.xlsx",sheet_name='Sheet1')
